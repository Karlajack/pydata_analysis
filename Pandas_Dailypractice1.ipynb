# %% [markdown]
# <a href="https://colab.research.google.com/github/Karlajack/pydata_analysis/blob/main/Pandas_Dailypractice1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# 	evolution	hp	name	pokedex	type
# 0	Ivysaur	45	Bulbasaur	yes	grass
# 1	Charmeleon	39	Charmander	no	fire
# 2	Wartortle	44	Squirtle	yes	water
# 3	Metapod	45	Caterpie	no	bug

# %% [markdown]
# Step 2. Create a data dictionary that looks like the DataFrame below
# Step 3. Assign it to a variable called pokemon

# %%
data={'evolution':['Ivysaur','Charmeleon','Wartortle','Metapod'],'hp':[45,39,44,45],'name':['Bulbasaur','Charmander','Squirtle','Caterpie'],'pokedex':['yes','no','yes','no'],'type':['grass','fire','water','bug']}

# %%
data
# Out:
# {'evolution': ['Ivysaur', 'Charmeleon', 'Wartortle', 'Metapod'],
#  'hp': [45, 39, 44, 45],
#  'name': ['Bulbasaur', 'Charmander', 'Squirtle', 'Caterpie'],
#  'pokedex': ['yes', 'no', 'yes', 'no'],
#  'type': ['grass', 'fire', 'water', 'bug']}

# %%
pokemon=pd.DataFrame(data)
pokemon
# Out:
#     evolution  hp        name pokedex   type
# 0     Ivysaur  45   Bulbasaur     yes  grass
# 1  Charmeleon  39  Charmander      no   fire
# 2   Wartortle  44    Squirtle     yes  water
# 3     Metapod  45    Caterpie      no    bug

# %% [markdown]
# Step 4. Ops...it seems the DataFrame columns are in alphabetical order. Place the order of the columns as name, type, hp, evolution, pokedex

# %%
data={'name':['Bulbasaur','Charmander','Squirtle','Caterpie'],'type':['grass','fire','water','bug'], 'hp':[45,39,44,45],'evolution':['Ivysaur','Charmeleon','Wartortle','Metapod'],'pokedex':['yes','no','yes','no']}

# %%
pokemon=pd.DataFrame(data)
pokemon
# Out:
#          name   type  hp   evolution pokedex
# 0   Bulbasaur  grass  45     Ivysaur     yes
# 1  Charmander   fire  39  Charmeleon      no
# 2    Squirtle  water  44   Wartortle     yes
# 3    Caterpie    bug  45     Metapod      no

# %%
data={'name':['Bulbasaur','Charmander','Squirtle','Caterpie'],'type':['grass','fire','water','bug'],'place':['texas','washington','newyork','illinois'],'hp':[45,39,44,45],'evolution':['Ivysaur','Charmeleon','Wartortle','Metapod'],'pokedex':['yes','no','yes','no']}

# %%
pokemon=pd.DataFrame(data)
pokemon
# Out:
#          name   type       place  hp   evolution pokedex
# 0   Bulbasaur  grass       texas  45     Ivysaur     yes
# 1  Charmander   fire  washington  39  Charmeleon      no
# 2    Squirtle  water     newyork  44   Wartortle     yes
# 3    Caterpie    bug    illinois  45     Metapod      no

# %% [markdown]
# Step 6. Present the type of each column

# %%
pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       4 non-null      object
#  1   type       4 non-null      object
#  2   place      4 non-null      object
#  3   hp         4 non-null      int64
#  4   evolution  4 non-null      object
#  5   pokedex    4 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 320.0+ bytes

# %% [markdown]
# Whats the sum of hp?

# %%
pokemon['hp'].sum()
# Out:
# 173
