# %% [markdown]
# <a href="https://colab.research.google.com/github/Karlajack/pydata_analysis/blob/main/pandasdailypractice4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Chipotle

# %% [markdown]
# Step 2. Import the dataset from this address.
# Step 3. Assign it to a variable called chipo.

# %%
url='https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'

chipo=pd.read_csv(url,sep='\t')
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# 1                                          [Clementine]     $3.39
# 2                                               [Apple]     $3.39
# 3                                                   NaN     $2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# ...                                                 ...        ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75
#
# [4622 rows x 5 columns]

# %% [markdown]
# Step 4. See the first 10 entries

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 6                                                NaN     $1.69
# 7  [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# 8  [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...     $9.25
# 9  [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25

# %% [markdown]
# Step 5. What is the number of observations in the dataset?

# %%
chipo.shape[0]
# Out:
# 4622

# %%
chipo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %% [markdown]
# Step 6. What is the number of columns in the dataset?

# %%
chipo.shape[1]
# Out:
# 5

# %% [markdown]
# Step 7. Print the name of all the columns.

# %%
chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %% [markdown]
# Step 8. How is the dataset indexed?

# %%
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %% [markdown]
# Step 9. Which was the most-ordered item?

# %%
t = chipo.groupby('item_name').sum()
c = t.sort_values(['quantity'], ascending = False)
c.head(1)
# Out:
#               order_id  quantity  \
# item_name
# Chicken Bowl    713926       761
#
#                                              choice_description  \
# item_name
# Chicken Bowl  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...
#
#                                                      item_price
# item_name
# Chicken Bowl  $16.98 $10.98 $11.25 $8.75 $8.49 $11.25 $8.75 ...

# %% [markdown]
# Step 10. For the most-ordered item, how many items were ordered?

# %%
c.iloc[0:1,1:2]
# Out:
#               quantity
# item_name
# Chicken Bowl       761

# %% [markdown]
# Step 11. What was the most ordered item in the choice_description column?

# %%
c = chipo.groupby('choice_description').sum()
d = c.sort_values(['quantity'], ascending = False)
d.head(1)
# Out:
#                     order_id  quantity  \
# choice_description
# [Diet Coke]           123455       159
#
#                                                             item_name  \
# choice_description
# [Diet Coke]         Canned SodaCanned SodaCanned Soda6 Pack Soft D...
#
#                                                            item_price
# choice_description
# [Diet Coke]         $2.18 $1.09 $1.09 $6.49 $2.18 $1.25 $1.09 $6.4...

# %% [markdown]
# Step 12. How many items were orderd in total?

# %%
chipo['quantity'].sum()
# Out:
# 4972

# %% [markdown]
# Step 13. Turn the item price into a float
# Step 13.a. Check the item price type

# %%
chipo.item_price.dtype
# Out:
# dtype('O')

# %% [markdown]
# Step 13.b. Create a lambda function and change the type of item price

# %%
func = lambda x: float(x[1:-1])
chipo.item_price = chipo.item_price.apply(func)

# %% [markdown]
# Step 13.c. Check the item price type

# %%
chipo['item_price'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# Step 14. How much was the revenue for the period in the dataset?

# %%
revenue = (chipo['quantity'] * chipo['item_price']).sum()
revenue
# Out:
# 39237.02

# %% [markdown]
# Step 15. How many orders were made in the period?

# %%
orders = chipo.order_id.value_counts().count()
orders
# Out:
# 1834

# %% [markdown]
# Step 16. What is the average revenue amount per order?

# %%
chipo['revenue'] = chipo['quantity'] * chipo['item_price']
order_group = chipo.groupby(by=['order_id']).sum()
order_group.mean()['revenue']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1679             try:
# -> 1680                 x = x.astype(np.complex128)
#    1681             except (TypeError, ValueError):
#
# ValueError: complex() arg is a malformed string
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1682                 try:
# -> 1683                     x = x.astype(np.float64)
#    1684                 except ValueError as err:
#
# ValueError: could not convert string to float: 'Chips and Fresh Tomato SalsaIzzeNantucket NectarChips and Tomatillo-Green Chili SalsaChicken BowlChicken BowlSide of ChipsSteak BurritoSteak Soft TacosSteak BurritoChips and GuacamoleChicken Crispy TacosChicken Soft TacosChicken BowlChips and GuacamoleChips and Tomatillo-Green Chili SalsaChicken BurritoChicken BurritoCanned SodaChicken BowlChips and GuacamoleBarbacoa BurritoNantucket NectarChicken BurritoIzzeChips and Fresh Tomato SalsaChicken BowlCarnitas BurritoCanned SodaChicken BurritoChips and Tomatillo-Green Chili SalsaSteak BurritoSide of ChipsCarnitas BowlBottled WaterChicken Soft TacosChicken Soft TacosChips and GuacamoleChips and Tomatillo Green Chili SalsaBarbacoa BowlChipsChips and GuacamoleChicken BowlSteak BurritoChicken Salad BowlChicken BurritoSteak BurritoIzzeSteak BurritoChips and GuacamoleSteak BurritoCanned SodaChicken BurritoCanned SodaSteak BowlChips and Fresh Tomato SalsaBarbacoa Soft TacosVeggie BurritoBarbacoa BowlChipsChips and GuacamoleSteak Soft TacosVeggie BowlChicken BurritoSteak BurritoSteak Soft TacosIzzeSteak BurritoChicken BurritoSteak BurritoSide of ChipsSteak BurritoChips and GuacamoleChicken BurritoChips and GuacamoleChicken Soft TacosChicken BowlChipsChicken BowlChicken Soft TacosChipsBarbacoa BurritoChicken BurritoChicken BurritoSteak Soft TacosVeggie BowlSteak BowlBottled WaterCarnitas BurritoChips and Fresh Tomato SalsaSteak BowlSteak BowlSteak Crispy TacosCarnitas BurritoCh...
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-013fd3a3657d> in <cell line: 3>()
#       1 chipo['revenue'] = chipo['quantity'] * chipo['item_price']
#       2 order_group = chipo.groupby(by=['order_id']).sum()
# ----> 3 order_group.mean()['revenue']
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   11554             **kwargs,
#   11555         ):
# > 11556             return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11557
#   11558         setattr(cls, "mean", mean)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   11199         **kwargs,
#   11200     ) -> Series | float:
# > 11201         return self._stat_function(
#   11202             "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11203         )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11156         validate_bool_kwarg(skipna, "skipna", none_allowed=False)
#   11157
# > 11158         return self._reduce(
#   11159             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11160         )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   10517         # After possibly _get_data and transposing, we are now in the
#   10518         #  simple case where we can use BlockManager.reduce
# > 10519         res = df._mgr.reduce(blk_func)
#   10520         out = df._constructor(res).iloc[0]
#   10521         if out_dtype is not None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in reduce(self, func)
#    1532         res_blocks: list[Block] = []
#    1533         for blk in self.blocks:
# -> 1534             nbs = blk.reduce(func)
#    1535             res_blocks.extend(nbs)
#    1536
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/blocks.py in reduce(self, func)
#     337         assert self.ndim == 2
#     338
# --> 339         result = func(self.values)
#     340
#     341         if self.values.ndim == 1:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in blk_func(values, axis)
#   10480                 return values._reduce(name, skipna=skipna, **kwds)
#   10481             else:
# > 10482                 return op(values, axis=axis, skipna=skipna, **kwds)
#   10483
#   10484         def _get_data() -> DataFrame:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      94             try:
#      95                 with np.errstate(invalid="ignore"):
# ---> 96                     return f(*args, **kwargs)
#      97             except ValueError as e:
#      98                 # we want to transform an object array
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     156                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157             else:
# --> 158                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     159
#     160             return result
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in new_func(values, axis, skipna, mask, **kwargs)
#     419             mask = isna(values)
#     420
# --> 421         result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     422
#     423         if datetimelike:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in nanmean(values, axis, skipna, mask)
#     725
#     726     count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 727     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     728
#     729     if axis is not None and getattr(the_sum, "ndim", False):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1684                 except ValueError as err:
#    1685                     # GH#29941 we get here with object arrays containing strs
# -> 1686                     raise TypeError(f"Could not convert {x} to numeric") from err
#    1687             else:
#    1688                 if not np.any(np.imag(x)):
#
# TypeError: Could not convert ['Chips and Fresh Tomato SalsaIzzeNantucket NectarChips and Tomatillo-Green Chili SalsaChicken BowlChicken BowlSide of ChipsSteak BurritoSteak Soft TacosSteak BurritoChips and GuacamoleChicken Crispy TacosChicken Soft TacosChicken BowlChips and GuacamoleChips and Tomatillo-Green Chili SalsaChicken BurritoChicken BurritoCanned SodaChicken BowlChips and GuacamoleBarbacoa BurritoNantucket NectarChicken BurritoIzzeChips and Fresh Tomato SalsaChicken BowlCarnitas BurritoCanned SodaChicken BurritoChips and Tomatillo-Green Chili SalsaSteak BurritoSide of ChipsCarnitas BowlBottled WaterChicken Soft TacosChicken Soft TacosChips and GuacamoleChips and Tomatillo Green Chili SalsaBarbacoa BowlChipsChips and GuacamoleChicken BowlSteak BurritoChicken Salad BowlChicken BurritoSteak BurritoIzzeSteak BurritoChips and GuacamoleSteak BurritoCanned SodaChicken BurritoCanned SodaSteak BowlChips and Fresh Tomato SalsaBarbacoa Soft TacosVeggie BurritoBarbacoa BowlChipsChips and GuacamoleSteak Soft TacosVeggie BowlChicken BurritoSteak BurritoSteak Soft TacosIzzeSteak BurritoChicken BurritoSteak BurritoSide of ChipsSteak BurritoChips and GuacamoleChicken BurritoChips and GuacamoleChicken Soft TacosChicken BowlChipsChicken BowlChicken Soft TacosChipsBarbacoa BurritoChicken BurritoChicken BurritoSteak Soft TacosVeggie BowlSteak BowlBottled WaterCarnitas BurritoChips and Fresh Tomato SalsaSteak BowlSteak BowlSteak Crispy TacosCarnitas BurritoChips and Guacamole...

# %% [markdown]
# Step 17. How many different items are sold?

# %%
chipo[['item_name']].value_counts().count()
# Out:
# 50

# %% [markdown]
# **Occupation**

# %% [markdown]
# Step 2. Import the dataset from this address.
#
# Step 3. Assign it to a variable called users and use the 'user_id' as index

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user'
user_id = pd.read_csv(url, sep='|')
user_id
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %% [markdown]
# Step 4. See the first 25 entries

# %%
user_id.head(25)
# Out:
#     user_id  age gender     occupation zip_code
# 0         1   24      M     technician    85711
# 1         2   53      F          other    94043
# 2         3   23      M         writer    32067
# 3         4   24      M     technician    43537
# 4         5   33      F          other    15213
# 5         6   42      M      executive    98101
# 6         7   57      M  administrator    91344
# 7         8   36      M  administrator    05201
# 8         9   29      M        student    01002
# 9        10   53      M         lawyer    90703
# 10       11   39      F          other    30329
# 11       12   28      F          other    06405
# 12       13   47      M       educator    29206
# 13       14   45      M      scientist    55106
# 14       15   49      F       educator    97301
# 15       16   21      M  entertainment    10309
# 16       17   30      M     programmer    06355
# 17       18   35      F          other    37212
# 18       19   40      M      librarian    02138
# 19       20   42      F      homemaker    95660
# 20       21   26      M         writer    30068
# 21       22   25      M         writer    40206
# 22       23   30      F         artist    48197
# 23       24   21      F         artist    94533
# 24       25   39      M       engineer    55107

# %% [markdown]
# Step 5. See the last 10 entries

# %%
user_id.tail(10)
# Out:
#      user_id  age gender     occupation zip_code
# 933      934   61      M       engineer    22902
# 934      935   42      M         doctor    66221
# 935      936   24      M          other    32789
# 936      937   48      M       educator    98072
# 937      938   38      F     technician    55038
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841

# %% [markdown]
# Step 6. What is the number of observations in the dataset?

# %%
user_id.info()
user_id.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 943 entries, 0 to 942
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     943 non-null    int64
#  1   age         943 non-null    int64
#  2   gender      943 non-null    object
#  3   occupation  943 non-null    object
#  4   zip_code    943 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 37.0+ KB
# (943, 5)

# %% [markdown]
# Step 7. What is the number of columns in the dataset?

# %%
user_id.shape[1]
# Out:
# 5

# %% [markdown]
# Step 8. Print the name of all the columns.

# %%
user_id.columns
# Out:
# Index(['user_id', 'age', 'gender', 'occupation', 'zip_code'], dtype='object')

# %% [markdown]
# Step 9. How is the dataset indexed?

# %%
user_id.index
# Out:
# RangeIndex(start=0, stop=943, step=1)

# %% [markdown]
# Step 10. What is the data type of each column?

# %%
user_id.dtypes
# Out:
# user_id        int64
# age            int64
# gender        object
# occupation    object
# zip_code      object
# dtype: object

# %% [markdown]
# Step 11. Print only the occupation column

# %%
user_id['occupation']
# Out:
# 0         technician
# 1              other
# 2             writer
# 3         technician
# 4              other
#            ...
# 938          student
# 939    administrator
# 940          student
# 941        librarian
# 942          student
# Name: occupation, Length: 943, dtype: object

# %% [markdown]
# Step 12. How many different occupations are in this dataset?

# %%
user_id['occupation'].value_counts().count()
user_id.occupation.nunique()
# Out:
# 21

# %% [markdown]
# Step 13. What is the most frequent occupation?

# %%
user_id.occupation.value_counts().head(1)
# Out:
# occupation
# student    196
# Name: count, dtype: int64

# %% [markdown]
# Step 14. Summarize the DataFrame.

# %%
user_id.describe()
# Out:
#           user_id         age
# count  943.000000  943.000000
# mean   472.000000   34.051962
# std    272.364951   12.192740
# min      1.000000    7.000000
# 25%    236.500000   25.000000
# 50%    472.000000   31.000000
# 75%    707.500000   43.000000
# max    943.000000   73.000000

# %% [markdown]
# Step 15. Summarize all the columns

# %%
user_id.describe(include = 'all')
# Out:
#            user_id         age gender occupation zip_code
# count   943.000000  943.000000    943        943      943
# unique         NaN         NaN      2         21      795
# top            NaN         NaN      M    student    55414
# freq           NaN         NaN    670        196        9
# mean    472.000000   34.051962    NaN        NaN      NaN
# std     272.364951   12.192740    NaN        NaN      NaN
# min       1.000000    7.000000    NaN        NaN      NaN
# 25%     236.500000   25.000000    NaN        NaN      NaN
# 50%     472.000000   31.000000    NaN        NaN      NaN
# 75%     707.500000   43.000000    NaN        NaN      NaN
# max     943.000000   73.000000    NaN        NaN      NaN

# %% [markdown]
# Step 16. Summarize only the occupation column

# %%
user_id['occupation'].describe()
# Out:
# count         943
# unique         21
# top       student
# freq          196
# Name: occupation, dtype: object

# %% [markdown]
# Step 17. What is the mean age of users?

# %%
user_id['age'].mean()
# Out:
# 34.05196182396607

# %% [markdown]
# Step 18. What is the age with least occurrence?

# %%
user_id['age'].value_counts().tail()
# Out:
# age
# 7     1
# 66    1
# 11    1
# 10    1
# 73    1
# Name: count, dtype: int64

# %% [markdown]
# **World Food Facts**

# %% [markdown]
# Step 1. Go to https://www.kaggle.com/openfoodfacts/world-food-facts/data
#
# Step 2. Download the dataset to your computer and unzip it.
#
# Step 3. Use the tsv file and assign it to a dataframe called food

# %%
food = pd.read_table('/content/en.openfoodfacts.org.products.tsv',sep='\t')
food
# Out:
# <ipython-input-133-f55f0773aa51>:1: DtypeWarning: Columns (19,20,24,25,26,28,37,38,39,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   food = pd.read_table('/content/en.openfoodfacts.org.products.tsv',sep='\t')
#               code                                                url  \
# 0             3087  http://world-en.openfoodfacts.org/product/0000...
# 1             4530  http://world-en.openfoodfacts.org/product/0000...
# 2             4559  http://world-en.openfoodfacts.org/product/0000...
# 3            16087  http://world-en.openfoodfacts.org/product/0000...
# 4            16094  http://world-en.openfoodfacts.org/product/0000...
# ...            ...                                                ...
# 79907  72080135200  http://world-en.openfoodfacts.org/product/0072...
# 79908  72080140105  http://world-en.openfoodfacts.org/product/0072...
# 79909  72080140204  http://world-en.openfoodfacts.org/product/0072...
# 79910  72080140303  http://world-en.openfoodfacts.org/product/0072...
# 79911  72080157103  http://world-en.openfoodfacts.org/product/0072...
#
#                           creator   created_t      created_datetime  \
# 0      openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# 1                 usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 2                 usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 3                 usda-ndb-import  1489055731  2017-03-09T10:35:31Z
# 4                 usda-ndb-import  1489055653  2017-03-09T10:34:13Z
# ...                           ...         ...                   ...
# 79907             usda-ndb-import  1489071636  2017-03-09T15:00:36Z
# 79908             usda-ndb-import  1489072502  2017-03-09T15:15:02Z
# 79909             usda-ndb-import  1489072503  2017-03-09T15:15:03Z
# 79910             usda-ndb-import  1489073471  2017-03-09T15:31:11Z
# 79911             usda-ndb-import  1489074490  2017-03-09T15:48:10Z
#
#        last_modified_t last_modified_datetime                    product_name  \
# 0           1474103893   2016-09-17T09:18:13Z              Farine de blé noir
# 1           1489069957   2017-03-09T14:32:37Z  Banana Chips Sweetened (Whole)
# 2           1489069957   2017-03-09T14:32:37Z                         Peanuts
# 3           1489055731   2017-03-09T10:35:31Z          Organic Salted Nut Mix
# 4           1489055653   2017-03-09T10:34:13Z                 Organic Polenta
# ...                ...                    ...                             ...
# 79907       1489071636   2017-03-09T15:00:36Z                      Corn Chips
# 79908       1489072502   2017-03-09T15:15:02Z    Tortilla Chips, Nacho Cheese
# 79909       1489072503   2017-03-09T15:15:03Z    Nacho Tortilla Chips, Cheese
# 79910       1489073471   2017-03-09T15:31:11Z    Tortilla Chips, Nacho Cheese
# 79911       1489074490   2017-03-09T15:48:10Z     Pretzel Minis, Frosty Cream
#
#       generic_name quantity  ... fruits-vegetables-nuts_100g  \
# 0              NaN      1kg  ...                         NaN
# 1              NaN      NaN  ...                         NaN
# 2              NaN      NaN  ...                         NaN
# 3              NaN      NaN  ...                         NaN
# 4              NaN      NaN  ...                         NaN
# ...            ...      ...  ...                         ...
# 79907          NaN      NaN  ...                         NaN
# 79908          NaN      NaN  ...                         NaN
# 79909          NaN      NaN  ...                         NaN
# 79910          NaN      NaN  ...                         NaN
# 79911          NaN      NaN  ...                         NaN
#
#       fruits-vegetables-nuts-estimate_100g collagen-meat-protein-ratio_100g  \
# 0                                      NaN                              NaN
# 1                                      NaN                              NaN
# 2                                      NaN                              NaN
# 3                                      NaN                              NaN
# 4                                      NaN                              NaN
# ...                                    ...                              ...
# 79907                                  NaN                              NaN
# 79908                                  NaN                              NaN
# 79909                                  NaN                              NaN
# 79910                                  NaN                              NaN
# 79911                                  NaN                              NaN
#
#       cocoa_100g chlorophyl_100g carbon-footprint_100g  \
# 0            NaN             NaN                   NaN
# 1            NaN             NaN                   NaN
# 2            NaN             NaN                   NaN
# 3            NaN             NaN                   NaN
# 4            NaN             NaN                   NaN
# ...          ...             ...                   ...
# 79907        NaN             NaN                   NaN
# 79908        NaN             NaN                   NaN
# 79909        NaN             NaN                   NaN
# 79910        NaN             NaN                   NaN
# 79911        NaN             NaN                   NaN
#
#       nutrition-score-fr_100g nutrition-score-uk_100g glycemic-index_100g  \
# 0                         NaN                     NaN                 NaN
# 1                        14.0                    14.0                 NaN
# 2                         0.0                     0.0                 NaN
# 3                        12.0                    12.0                 NaN
# 4                         NaN                     NaN                 NaN
# ...                       ...                     ...                 ...
# 79907                    19.0                    19.0                 NaN
# 79908                    14.0                    14.0                 NaN
# 79909                    14.0                    14.0                 NaN
# 79910                    14.0                    14.0                 NaN
# 79911                     NaN                     NaN                 NaN
#
#       water-hardness_100g
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 79907                 NaN
# 79908                 NaN
# 79909                 NaN
# 79910                 NaN
# 79911                 NaN
#
# [79912 rows x 163 columns]

# %% [markdown]
# Step 4. See the first 5 entries

# %%
food.head()
# Out:
#     code                                                url  \
# 0   3087  http://world-en.openfoodfacts.org/product/0000...
# 1   4530  http://world-en.openfoodfacts.org/product/0000...
# 2   4559  http://world-en.openfoodfacts.org/product/0000...
# 3  16087  http://world-en.openfoodfacts.org/product/0000...
# 4  16094  http://world-en.openfoodfacts.org/product/0000...
#
#                       creator   created_t      created_datetime  \
# 0  openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# 1             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 2             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 3             usda-ndb-import  1489055731  2017-03-09T10:35:31Z
# 4             usda-ndb-import  1489055653  2017-03-09T10:34:13Z
#
#    last_modified_t last_modified_datetime                    product_name  \
# 0       1474103893   2016-09-17T09:18:13Z              Farine de blé noir
# 1       1489069957   2017-03-09T14:32:37Z  Banana Chips Sweetened (Whole)
# 2       1489069957   2017-03-09T14:32:37Z                         Peanuts
# 3       1489055731   2017-03-09T10:35:31Z          Organic Salted Nut Mix
# 4       1489055653   2017-03-09T10:34:13Z                 Organic Polenta
#
#   generic_name quantity  ... fruits-vegetables-nuts_100g  \
# 0          NaN      1kg  ...                         NaN
# 1          NaN      NaN  ...                         NaN
# 2          NaN      NaN  ...                         NaN
# 3          NaN      NaN  ...                         NaN
# 4          NaN      NaN  ...                         NaN
#
#   fruits-vegetables-nuts-estimate_100g collagen-meat-protein-ratio_100g  \
# 0                                  NaN                              NaN
# 1                                  NaN                              NaN
# 2                                  NaN                              NaN
# 3                                  NaN                              NaN
# 4                                  NaN                              NaN
#
#   cocoa_100g chlorophyl_100g carbon-footprint_100g nutrition-score-fr_100g  \
# 0        NaN             NaN                   NaN                     NaN
# 1        NaN             NaN                   NaN                    14.0
# 2        NaN             NaN                   NaN                     0.0
# 3        NaN             NaN                   NaN                    12.0
# 4        NaN             NaN                   NaN                     NaN
#
#   nutrition-score-uk_100g glycemic-index_100g water-hardness_100g
# 0                     NaN                 NaN                 NaN
# 1                    14.0                 NaN                 NaN
# 2                     0.0                 NaN                 NaN
# 3                    12.0                 NaN                 NaN
# 4                     NaN                 NaN                 NaN
#
# [5 rows x 163 columns]

# %% [markdown]
# Step 5. What is the number of observations in the dataset?

# %%
food.shape[0]
# Out:
# 79912

# %% [markdown]
# Step 6. What is the number of columns in the dataset?

# %%
food.shape[1]
# Out:
# 163

# %% [markdown]
# Step 7. Print the name of all the columns.

# %%
food.columns
# Out:
# Index(['code', 'url', 'creator', 'created_t', 'created_datetime',
#        'last_modified_t', 'last_modified_datetime', 'product_name',
#        'generic_name', 'quantity',
#        ...
#        'fruits-vegetables-nuts_100g', 'fruits-vegetables-nuts-estimate_100g',
#        'collagen-meat-protein-ratio_100g', 'cocoa_100g', 'chlorophyl_100g',
#        'carbon-footprint_100g', 'nutrition-score-fr_100g',
#        'nutrition-score-uk_100g', 'glycemic-index_100g',
#        'water-hardness_100g'],
#       dtype='object', length=163)

# %% [markdown]
# Step 8. What is the name of 105th column?

# %%
food.columns[105]
# Out:
# '-fructose_100g'

# %% [markdown]
# Step 9. What is the type of the observations of the 105th column?

# %%
food.dtypes[105]
# Out:
# dtype('float64')

# %% [markdown]
# Step 10. How is the dataset indexed?¶

# %%
food.index
# Out:
# RangeIndex(start=0, stop=79912, step=1)

# %% [markdown]
# Step 11. What is the product name of the 19th observation?

# %%
food['product_name'][105]
# Out:
# 'Split Pea Soup Mix'
